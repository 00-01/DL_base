# %%
import ast
import csv
from glob import glob
import json
import os
from tkinter import *
from tkinter import filedialog, messagebox
import traceback

import cv2
from IPython.core.display import Math
from IPython.core.display_functions import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image, ImageTk


# def histogramer(img):
#     im = img.flatten()
#     # counts, bins = np.histogram(im, range=(0,255))
#     # plot histogram centered on values 0..255
#     # plt.bar(bins[:-1]-0.5, counts, width=1, edgecolor='none')
#     # plt.bar(bins[:-1]-0.5, counts, width=1, edgecolor='none')
#     # plt.xlim([-0.5, 255.5])
#     plt.hist(im, bins=range(img.min(), img.max(), 1), histtype='bar', edgecolor='red', color='red')
#
#     # n, bins, patches = plt.hist(x=im, bins='auto', color='#0504aa', alpha=0.7)
#     # plt.grid(axis='both', alpha=0.5)
#     # plt.xlabel('Value')
#     # plt.ylabel('Frequency')
#     # Set a clean upper y-axis limit.
#     # maxfreq = n.max()
#     # plt.ylim(ymax=np.ceil(maxfreq/10)*10 if maxfreq%10 else maxfreq+10)
#     plt.show()

# %%
ir = f"../OUTPUTS/out_img.png"
img_arr = cv2.imread(ir, 0)
# img_arr = np.resize(img_arr, (80,80))
img = Image.fromarray(img_arr)

# histogramer(img_arr)
display(img)
# Out:
# <PIL.Image.Image image mode=L size=640x640>

# %%
img_arr.shape
# Out:
# (640, 640)

# %%
def arr_2_histArr(img_arr):
    total_pixel = 0
    total_value = 0
    hist_arr = np.zeros((np.max(img_arr)+1), dtype=int)
    for row in img_arr:
        for value in row:
            hist_arr[value] += 1
            total_pixel += 1
            total_value += value
    return hist_arr, total_value, total_pixel


fig = plt.figure()
hist_arr, total_value, total_pixel = arr_2_histArr(img_arr)
print(f"total_value: {total_value} {chr(10)}total_pixel: {total_pixel}")
# plt.bar(range(len(hist_arr)), hist_arr, color='blue')
plt.plot(range(len(hist_arr)), hist_arr, color='blue')
plt.show()
# Out:
# total_value: 31832000
# total_pixel: 409600

# %%
norm_hist = hist_arr/total_pixel
norm_hist[-8:]
# Out:
# array([0.00078125, 0.00046875, 0.000625  , 0.00046875, 0.00078125,
#        0.00046875, 0.00046875, 0.0565625 ])

# %%
def arr_2_cum_histArr(arr):
    cum = 0
    cum_hist_arr = np.zeros(len(arr), dtype=int)
    for idx, val in enumerate(hist_arr):
        cum += val
        cum_hist_arr[idx] += cum
    return cum_hist_arr

cum_hist_arr = arr_2_cum_histArr(norm_hist)
print(cum_hist_arr[-8:])
print(cum_hist_arr.shape)
plt.plot(range(len(cum_hist_arr)), cum_hist_arr, color='blue')
plt.show()
# Out:
# [385088 385280 385536 385728 386048 386240 386432 409600]
# (256,)

# %%
display(Math(r's_k = \sum_{j=0}^{k} {\frac{n_j}{N}}'))
# Out:
# $\displaystyle s_k = \sum_{j=0}^{k} {\frac{n_j}{N}}$

# %%
LUT = np.round(255*cum_hist_arr).astype(np.uint8)
LUT
# Out:
# (256,)

# %%
# img_list = list(img_arr.flatten())
img_arr_1D = np.reshape(img_arr, (img_arr.shape[0]*img_arr.shape[1]))
# img_arr_1D.shape
# img_list[:9]
# img_arr_1D

# %%
eq_img_arr = np.zeros((img_arr_1D.shape[0]))
# eq_img_list1 = [LUT[p] for p in img_arr_1D]
# eq_img_list1[-9:]
for i, j in enumerate(img_arr_1D):
    eq_img_arr[i] = LUT[j]
eq_img_arr[-8:]
# Out:
# array([128., 128., 128., 128., 128., 128., 128., 128.])

# %%
eq_img_arr1 = np.reshape(eq_img_arr, (img_arr.shape))
eq_img_arr1.shape
# Out:
# (640, 640)

# %%
a = Image.fromarray(eq_img_arr1, 'L')
display(a)
# Out:
# <PIL.Image.Image image mode=L size=640x640>

# %%
# transform pixel values to equalize
eq_img_list = [LUT[p] for p in img_list]
ll = np.array(eq_img_list)
#convert NumPy array to pillow Image and write to file
# eq_img_array = np.reshape(np.asarray(eq_img_list), img_array.shape)
# eq_img = Image.fromarray(eq_img_array, mode='L')
plt.bar(range(len(ll)), ll, color='blue')
# plt.plot(range(len(ll)), ll, color='blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [105], in <cell line: 7>()
#       3 ll = np.array(eq_img_list)
#       4 #convert NumPy array to pillow Image and write to file
#       5 # eq_img_array = np.reshape(np.asarray(eq_img_list), img_array.shape)
#       6 # eq_img = Image.fromarray(eq_img_array, mode='L')
# ----> 7 plt.bar(range(len(ll)), ll, color='blue')
#       8 # plt.plot(range(len(ll)), ll, color='blue')
#       9 plt.show()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2651, in bar(x, height, width, bottom, align, data, **kwargs)
#    2647 @_copy_docstring_and_deprecators(Axes.bar)
#    2648 def bar(
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py:1361, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1358 @functools.wraps(func)
#    1359 def inner(ax, *args, data=None, **kwargs):
#    1360     if data is None:
# -> 1361         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1363     bound = new_sig.bind(ax, *args, **kwargs)
#    1364     auto_label = (bound.arguments.get(label_namer)
#    1365                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py:2371, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2369     elif orientation == 'horizontal':
#    2370         r.sticky_edges.x.append(l)
# -> 2371     self.add_patch(r)
#    2372     patches.append(r)
#    2374 if xerr is not None or yerr is not None:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:2170, in _AxesBase.add_patch(self, p)
#    2168 if p.get_clip_path() is None:
#    2169     p.set_clip_path(self.patch)
# -> 2170 self._update_patch_limits(p)
#    2171 self.patches.append(p)
#    2172 p._remove_method = self.patches.remove
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:2192, in _AxesBase._update_patch_limits(self, patch)
#    2189 vertices = p.vertices if p.codes is None else p.vertices[np.isin(
#    2190     p.codes, (mpath.Path.CLOSEPOLY, mpath.Path.STOP), invert=True)]
#    2191 if vertices.size > 0:
# -> 2192     xys = patch.get_patch_transform().transform(vertices)
#    2193     if patch.get_data_transform() != self.transData:
#    2194         patch_to_data = (patch.get_data_transform() -
#    2195                          self.transData)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/patches.py:779, in Rectangle.get_patch_transform(self)
#     772 def get_patch_transform(self):
#     773     # Note: This cannot be called until after this has been added to
#     774     # an Axes, otherwise unit conversion will fail. This makes it very
#     775     # important to call the accessor method and not directly access the
#     776     # transformation member variable.
#     777     bbox = self.get_bbox()
#     778     return (transforms.BboxTransformTo(bbox)
# --> 779             + transforms.Affine2D().rotate_deg_around(
#     780                 bbox.x0, bbox.y0, self.angle))
#
# KeyboardInterrupt:

# %%
hist *= 255
hist[:9]
# Out:
# array([12.3515625 ,  0.6375    ,  0.6375    ,  0.67734375,  0.31875   ,
#         0.478125  ,  0.43828125,  0.478125  ,  0.99609375])

# %%
plt.plot(range(len(hist)), hist, color='blue')
plt.show()

# %%
hist_arr[:9]
# Out:
# array([19840,  1024,  1024,  1088,   512,   768,   704,   768,  1600])

# %%
# normalized cumulative histogram
# chistogram_array = np.cumsum(hist_arr)
# chistogram_array[-3:]

# %%
# len(eq_img_list)

# %%
"""
STEP 2: Pixel mapping lookup table
"""
transform_map = np.floor(255*cum_hist_arr).astype(np.uint8)

"""
STEP 3: Transformation
"""
# flatten image array into 1D list
img_list = list(img_arr.flatten())

# transform pixel values to equalize
eq_img_list = [transform_map[p] for p in img_list]

# reshape and write back into img_array
eq_img_array = np.reshape(np.asarray(eq_img_list), img_arr.shape)

plt.plot(range(len(eq_img_list)), eq_img_list, color='blue')
plt.show()

# %%
# img_filename = 'input_image.jpg'
# save_filename = 'output_image.jpg'
# img = Image.open(img_filename).convert(mode='L')
# img_array = np.asarray(imgray)
img_array = img_arr
"""
STEP 1: Normalized cumulative histogram
"""
#flatten image array and calculate histogram via binning
histogram_array = np.bincount(img_array.flatten(), minlength=256)

#normalize
num_pixels = np.sum(histogram_array)
histogram_array = histogram_array/num_pixels

#normalized cumulative histogram
chistogram_array = np.cumsum(histogram_array)

"""
STEP 2: Pixel mapping lookup table
"""
transform_map = np.floor(255*chistogram_array).astype(np.uint8)

"""
STEP 3: Transformation
"""
# flatten image array into 1D list
img_list = list(img_array.flatten())

# transform pixel values to equalize
eq_img_list = [transform_map[p] for p in img_list]
ll = np.array(eq_img_list)
#convert NumPy array to pillow Image and write to file
# eq_img_array = np.reshape(np.asarray(eq_img_list), img_array.shape)
# eq_img = Image.fromarray(eq_img_array, mode='L')
plt.bar(range(len(ll)), ll, color='blue')
# plt.plot(range(len(ll)), ll, color='blue')
plt.show()

# %%
#create list of values 0-255
# pixels = []
# for x in range(256):
#     pixels.append(x)
pixels = hist_arr.tolist()

#set width and height of image
width, height = img_arr.size
size = width*height
counts = []

#for each intensity level
for i in pixels:
    temp = 0
    #traverse through the pixels
    for x in range(width):
        for y in range(height):
            #if pixel intensity is equal to intensity level increment counter
            if (img.getpixel((x, y)) == i):
                temp = temp+1
    #append frequency of intensity level
    counts.append(temp)

#initialize list for frequency probabilities
pdf = []
for i in counts:
    pdf.append(i/size)

#initialize list for cumulative probability
cdf = []
total = 0
for i in pdf:
    total = total+i
    cdf.append(total)

#intialize list for mapping cdf
tr = []
for i in cdf:
    t = round(i*255)
    tr.append(t)

#initialize list containing new frequencies for equalized hist
hs = []
for i in pixels:
    count = 0
    tot = 0
    for j in tr:
        if (j == i):
            tot = tot+counts[count]
        count = count+1
    hs.append(tot)

#plot equalized histogram
plt.bar(pixels, hs)
# plt.plot(hs)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [74], in <cell line: 8>()
#       5 pixels = hist_arr.tolist()
#       7 #set width and height of image
# ----> 8 width, height = img_arr.size
#       9 size = width*height
#      10 counts = []
#
# TypeError: cannot unpack non-iterable int object

# %%
thresh = 120
img_arr = np.array(img)
# img_arr
img_arr[img_arr < thresh] = 0
img_arr[img_arr > thresh] -= 40
img_arr[:270] = 0
img_arr[550:] = 0
img_arr[:,:120] = 0
img_arr[:,390:] = 0
img_arr[img_arr < 0] = 0

# img_arr

arr2img = Image.fromarray(img_arr)
arr2img
# Out:
# <PIL.Image.Image image mode=L size=640x640>

# %%
resized_image = cv2.resize(img_arr, (80,80))
histogramer(resized_image)

# %%
a = np.random.rand(80,80)
a = a*250
a = np.around(a, 0).astype(int)
# a[a > 253] = 50

# a
histogramer(a)
